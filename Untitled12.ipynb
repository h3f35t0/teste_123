# %% [markdown]
# <a href="https://colab.research.google.com/github/h3f35t0/teste_123/blob/criacao_formulario/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("carro")
# Out:
# carro
